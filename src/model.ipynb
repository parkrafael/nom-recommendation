# %% [markdown]
# ## Imports

# %%
import pandas as pd
import altair as alt

from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Data Cleaning

# %%
df = pd.read_json("data/yelp_academic_dataset_business.json", lines=True)

df.head()
# Out:
#               business_id                     name              address  \
# 0  6iYb2HFDywm3zjuRg0shjw      Oskar Blues Taproom         921 Pearl St
# 1  tCbdrRPZA0oiIYSmHG3J0w  Flying Elephants at PDX  7000 NE Airport Way
# 2  bvN78flM8NLprQ1a1y5dRg           The Reclaimory   4720 Hawthorne Ave
# 3  oaepsyvc0J17qwi8cfrOWg              Great Clips   2566 Enterprise Rd
# 4  PE9uqAjdw0E4-8mjGl3wVA        Crossfit Terminus  1046 Memorial Dr SE
#
#           city state postal_code   latitude   longitude  stars  review_count  \
# 0      Boulder    CO       80302  40.017544 -105.283348    4.0            86
# 1     Portland    OR       97218  45.588906 -122.593331    4.0           126
# 2     Portland    OR       97214  45.511907 -122.613693    4.5            13
# 3  Orange City    FL       32763  28.914482  -81.295979    3.0             8
# 4      Atlanta    GA       30316  33.747027  -84.353424    4.0            14
#
#    is_open                                         attributes  \
# 0        1  {'RestaurantsTableService': 'True', 'WiFi': 'u...
# 1        1  {'RestaurantsTakeOut': 'True', 'RestaurantsAtt...
# 2        1  {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 3        1  {'RestaurantsPriceRange2': '1', 'BusinessAccep...
# 4        1  {'GoodForKids': 'False', 'BusinessParking': '{...
#
#                                           categories  \
# 0  Gastropubs, Food, Beer Gardens, Restaurants, B...
# 1  Salad, Soup, Sandwiches, Delis, Restaurants, C...
# 2  Antiques, Fashion, Used, Vintage & Consignment...
# 3                         Beauty & Spas, Hair Salons
# 4  Gyms, Active Life, Interval Training Gyms, Fit...
#
#                                                hours
# 0  {'Monday': '11:0-23:0', 'Tuesday': '11:0-23:0'...
# 1  {'Monday': '5:0-18:0', 'Tuesday': '5:0-17:0', ...
# 2  {'Thursday': '11:0-18:0', 'Friday': '11:0-18:0...
# 3                                               None
# 4  {'Monday': '16:0-19:0', 'Tuesday': '16:0-19:0'...

# %%
df.dropna(subset=["attributes", "categories", "hours"], inplace=True)

df.isnull().any()
# Out:
# business_id     False
# name            False
# address         False
# city            False
# state           False
# postal_code     False
# latitude        False
# longitude       False
# stars           False
# review_count    False
# is_open         False
# attributes      False
# categories      False
# hours           False
# dtype: bool

# %%
df['categories'] = df['categories'].apply(lambda x: x.replace(" ", "").split(","))

df.head()
# Out:
#               business_id                     name              address  \
# 0  6iYb2HFDywm3zjuRg0shjw      Oskar Blues Taproom         921 Pearl St
# 1  tCbdrRPZA0oiIYSmHG3J0w  Flying Elephants at PDX  7000 NE Airport Way
# 2  bvN78flM8NLprQ1a1y5dRg           The Reclaimory   4720 Hawthorne Ave
# 4  PE9uqAjdw0E4-8mjGl3wVA        Crossfit Terminus  1046 Memorial Dr SE
# 5  D4JtQNTI4X3KcbzacDJsMw      Bob Likes Thai Food         3755 Main St
#
#         city state postal_code   latitude   longitude  stars  review_count  \
# 0    Boulder    CO       80302  40.017544 -105.283348    4.0            86
# 1   Portland    OR       97218  45.588906 -122.593331    4.0           126
# 2   Portland    OR       97214  45.511907 -122.613693    4.5            13
# 4    Atlanta    GA       30316  33.747027  -84.353424    4.0            14
# 5  Vancouver    BC         V5V  49.251342 -123.101333    3.5           169
#
#    is_open                                         attributes  \
# 0        1  {'RestaurantsTableService': 'True', 'WiFi': 'u...
# 1        1  {'RestaurantsTakeOut': 'True', 'RestaurantsAtt...
# 2        1  {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 4        1  {'GoodForKids': 'False', 'BusinessParking': '{...
# 5        1  {'GoodForKids': 'True', 'Alcohol': 'u'none'', ...
#
#                                           categories  \
# 0  [Gastropubs, Food, BeerGardens, Restaurants, B...
# 1  [Salad, Soup, Sandwiches, Delis, Restaurants, ...
# 2  [Antiques, Fashion, Used, Vintage&Consignment,...
# 4  [Gyms, ActiveLife, IntervalTrainingGyms, Fitne...
# 5                                [Restaurants, Thai]
#
#                                                hours
# 0  {'Monday': '11:0-23:0', 'Tuesday': '11:0-23:0'...
# 1  {'Monday': '5:0-18:0', 'Tuesday': '5:0-17:0', ...
# 2  {'Thursday': '11:0-18:0', 'Friday': '11:0-18:0...
# 4  {'Monday': '16:0-19:0', 'Tuesday': '16:0-19:0'...
# 5  {'Monday': '17:0-21:0', 'Tuesday': '17:0-21:0'...

# %%
df_food = df[df['categories'].apply(lambda x: 'Restaurants' in x)]

df_food.head()
# Out:
#                business_id                     name              address  \
# 0   6iYb2HFDywm3zjuRg0shjw      Oskar Blues Taproom         921 Pearl St
# 1   tCbdrRPZA0oiIYSmHG3J0w  Flying Elephants at PDX  7000 NE Airport Way
# 5   D4JtQNTI4X3KcbzacDJsMw      Bob Likes Thai Food         3755 Main St
# 12  HPA_qyMEddpAEtFof02ixg      Mr G's Pizza & Subs        474 Lowell St
# 13  ufCxltuh56FF4-ZFZ6cVhg           Sister Honey's    247 E Michigan St
#
#          city state postal_code   latitude   longitude  stars  review_count  \
# 0     Boulder    CO       80302  40.017544 -105.283348    4.0            86
# 1    Portland    OR       97218  45.588906 -122.593331    4.0           126
# 5   Vancouver    BC         V5V  49.251342 -123.101333    3.5           169
# 12    Peabody    MA       01960  42.541155  -70.973438    4.0            39
# 13    Orlando    FL       32806  28.513265  -81.374707    4.5           135
#
#     is_open                                         attributes  \
# 0         1  {'RestaurantsTableService': 'True', 'WiFi': 'u...
# 1         1  {'RestaurantsTakeOut': 'True', 'RestaurantsAtt...
# 5         1  {'GoodForKids': 'True', 'Alcohol': 'u'none'', ...
# 12        1  {'RestaurantsGoodForGroups': 'True', 'HasTV': ...
# 13        1  {'BusinessParking': '{'garage': False, 'street...
#
#                                            categories  \
# 0   [Gastropubs, Food, BeerGardens, Restaurants, B...
# 1   [Salad, Soup, Sandwiches, Delis, Restaurants, ...
# 5                                 [Restaurants, Thai]
# 12                         [Food, Pizza, Restaurants]
# 13  [Restaurants, American(New), Bakeries, Dessert...
#
#                                                 hours
# 0   {'Monday': '11:0-23:0', 'Tuesday': '11:0-23:0'...
# 1   {'Monday': '5:0-18:0', 'Tuesday': '5:0-17:0', ...
# 5   {'Monday': '17:0-21:0', 'Tuesday': '17:0-21:0'...
# 12  {'Monday': '11:0-21:0', 'Tuesday': '11:0-21:0'...
# 13  {'Tuesday': '11:0-18:0', 'Wednesday': '11:0-18...

# %% [markdown]
# ## Data Splitting

# %%
train_df, test_df = train_test_split(df_food, test_size=0.30, random_state=123)

# %%
train_df.shape
# Out:
# (29852, 14)

# %%
test_df.shape
# Out:
# (12794, 14)

# %% [markdown]
# ## Exploratory Data Analysis

# %%
states = pd.DataFrame(df[['state']].value_counts().reset_index())

alt.Chart(states).mark_bar().encode(
    x=alt.X('state:N', sort='-y'),
    y=alt.Y('count')
)
# Out:
# alt.Chart(...)

# %%
cities = pd.DataFrame(df[['city']].value_counts().reset_index())

alt.Chart(cities).mark_bar().encode(
    x=alt.X('city:N', sort='-y'),
    y=alt.Y('count')
)
# Out:
# alt.Chart(...)

# %%
bc_food = train_df[train_df['state'] == 'BC']

# %%
categories = pd.DataFrame(bc_food['categories'].value_counts().reset_index())

alt.Chart(categories).mark_bar().encode(
    x=alt.X('categories:N', sort='-y'),
    y='count:Q' 
)
# Out:
#                    business_id                           name  \
# 58536   LxxgaqxNAKEYeQ3C32LrYA   One Shot Asian Fusion Bistro
# 129392  b6mYGDUgl1PC5Bpfy6fc3A       Westley Military Surplus
# 110206  o22_Ixj-B5JHCBYYevXv9Q  Cho Sun BBQ Korean Restaurant
# 137181  EgM75hqM50IGdOxE4M10QA  Pomegranate Grillhouse & Cafe
# 33011   SFDEM4EU8fYAAaFe3OHkng             House of Empanadas
# ...                        ...                            ...
# 45123   VRIQwLCLYJqzmxzGCUUPOQ               Sip Bowl La Mian
# 90013   SHrLUxpK6LDt3N1f6QQb9A            RV’s Butter Kitchen
# 24644   FiC58EBZOGDtWrY5p12X2g                 Eh! Restaurant
# 127290  9yVdZHqGclsEkYLlmKdBpA      Original Tandoori Kitchen
# 59608   eNJlxmoRm3L7RWjcgbuXbQ        Jasmine Flower Shanghai
#
#                       address             city state postal_code   latitude  \
# 58536        8197 Main Street        Vancouver    BC     V5X 3L2  49.211167
# 129392           525 Front St  New Westminster    BC     V3L 1A4  49.203217
# 110206          3486 Kingsway        Vancouver    BC     V5R 5L6  49.231742
# 137181    4361 Gallant Avenue  North Vancouver    BC     V7G 1L1  49.326692
# 33011       976 Denman Street        Vancouver    BC     V6G 2M1  49.289621
# ...                       ...              ...   ...         ...        ...
# 45123           2255 W 41 Ave        Vancouver    BC     V6M 4L3  49.234805
# 90013          1355 Hornby St        Vancouver    BC     V6Z 1W7  49.276869
# 24644     1050 Alberni Street        Vancouver    BC     V6E 2A3  49.284625
# 127290       7215 Main Street        Vancouver    BC     V5X 3J3  49.219006
# 59608   8532 Granville Street        Vancouver    BC     V6P 4Z7  49.209225
#
#          longitude  stars  review_count  is_open  \
# 58536  -123.102191    3.0             5        0
# 129392 -122.906941    3.0             6        1
# 110206 -123.030398    3.0           156        1
# 137181 -122.950440    3.0            30        1
# 33011  -123.138044    3.0             9        0
# ...            ...    ...           ...      ...
# 45123  -123.158742    3.5            43        1
# 90013  -123.130848    4.5            18        1
# 24644  -123.123225    3.0            19        1
# 127290 -123.101867    3.0            58        1
# 59608  -123.140181    3.5            31        1
#
#                                                attributes  \
# 58536   {'RestaurantsAttire': 'u'casual'', 'Alcohol': ...
# 129392  {'BusinessParking': '{'garage': False, 'street...
# 110206  {'OutdoorSeating': 'False', 'RestaurantsReserv...
# 137181  {'GoodForKids': 'True', 'RestaurantsReservatio...
# 33011   {'BusinessParking': '{'garage': False, 'street...
# ...                                                   ...
# 45123   {'Ambience': '{'touristy': False, 'hipster': F...
# 90013   {'BusinessParking': '{'garage': False, 'street...
# 24644   {'NoiseLevel': 'u'quiet'', 'Alcohol': 'u'none'...
# 127290  {'BusinessParking': '{'garage': False, 'street...
# 59608   {'RestaurantsDelivery': 'False', 'RestaurantsT...
#
#                                                categories  \
# 58536                     [Korean, Japanese, Restaurants]
# 129392  [Restaurants, OutdoorGear, Fishing, Pizza, Hat...
# 110206                              [Korean, Restaurants]
# 137181               [Pizza, Restaurants, Cafes, Burgers]
# 33011                        [LatinAmerican, Restaurants]
# ...                                                   ...
# 45123                     [Restaurants, Noodles, Chinese]
# 90013                               [Indian, Restaurants]
# 24644   [American(New), Canadian(New), ModernEuropean,...
# 127290                              [Indian, Restaurants]
# 59608                              [Restaurants, Chinese]
#
#                                                     hours
# 58536   {'Monday': '11:0-21:0', 'Tuesday': '11:0-21:0'...
# 129392  {'Monday': '10:0-17:30', 'Tuesday': '10:0-17:3...
# 110206  {'Monday': '11:30-23:30', 'Tuesday': '11:30-23...
# 137181  {'Monday': '11:0-19:0', 'Wednesday': '11:0-20:...
# 33011   {'Monday': '8:0-21:0', 'Tuesday': '8:0-21:0', ...
# ...                                                   ...
# 45123   {'Monday': '0:0-0:0', 'Tuesday': '11:0-21:0', ...
# 90013   {'Monday': '12:0-21:0', 'Tuesday': '12:0-21:0'...
# 24644   {'Monday': '7:0-19:0', 'Tuesday': '7:0-19:0', ...
# 127290  {'Monday': '11:30-23:0', 'Tuesday': '11:30-23:...
# 59608   {'Monday': '11:0-22:0', 'Wednesday': '11:0-22:...
#
# [4242 rows x 14 columns]
